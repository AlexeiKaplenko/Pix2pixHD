# %%
# !sudo rm -r -f Pix2pixHD/checkpoints

# %%
import shutil
shutil.rmtree('checkpoints')

# %%
import os
import s3fs

fs = s3fs.S3FileSystem()

# %%
os.mkdir('checkpoint')

# %%
# !pip install dominate

# %%
# !pip install --upgrade tensorflow

# %%
# import boto3
# s3 = boto3.resource('s3')
# my_bucket = s3.Bucket('pix2pixhd-2/datasets/jewelry/train_A')

# for my_bucket_object in my_bucket.objects.all():
#     print(my_bucket_object)

# %%
# fs.ls('s3://pix2pixhd-2/datasets/jewelry/train_A')

# %%
image_paths = []

for image_path in sorted(fs.ls('s3://pix2pixhd-2/datasets/jewelry/train_A'))[1:]:
    image_paths.append('s3://'+image_path)

# %%
# image_paths

# %%
# !python train.py --name jewelry_1024p --dataroot s3://pix2pixhd-2/datasets/jewelry/ --netG local --ngf 32 --num_D 3 --label_nc 0 --no_instance --resize_or_crop crop --fineSize 1024  --load_pretrain checkpoint/jewelry_512p/ --tf_log --batchSize 1 --gpu_ids 0
# !python train.py --name jewelry_1024p --netG local --ngf 32 --num_D 3 --label_nc 0 --no_instance --resize_or_crop crop --fineSize 960  --load_pretrain checkpoint/jewelry_512p/ --tf_log --batchSize 2 --gpu_ids 0

# %%
# !python train.py --name jewelry_1024p --netG local --ngf 32 --num_D 3 --label_nc 0 --no_instance --resize_or_crop crop --loadSize 2048 --fineSize 1280 --dataroot s3://pix2pixhd-3/datasets/jewelry/ --load_pretrain checkpoint/jewelry_1024p/ --tf_log --batchSize 1 --gpu_ids 0 --continue_train --niter 1000 --niter_decay 100
# !python train.py --name jewelry_1024p --netG local --ngf 32 --num_D 3 --label_nc 0 --no_instance --resize_or_crop crop --loadSize 2048 --fineSize 1280  --load_pretrain checkpoint/jewelry_1024p/ --tf_log --batchSize 1 --gpu_ids 0 --niter 1000 --niter_decay 100

# %%
# !python train.py --name jewelry_1024p --netG local --ngf 32 --num_D 3 --label_nc 0 --no_instance --resize_or_crop crop --loadSize 2048 --fineSize 1280 --dataroot s3://pix2pixhd-3/datasets/jewelry/ --load_pretrain checkpoint/jewelry_1024p/ --tf_log --batchSize 1 --gpu_ids 0 --niter 1000 --niter_decay 100
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoint
# continue_train: False
# data_type: 32
# dataroot: s3://pix2pixhd-3/datasets/jewelry/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 1280
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 10.0
# loadSize: 2048
# load_features: False
# load_pretrain: checkpoint/jewelry_1024p/
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 8
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: jewelry_1024p
# ndf: 64
# nef: 16
# netG: local
# ngf: 32
# niter: 1000
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 3
# ...
